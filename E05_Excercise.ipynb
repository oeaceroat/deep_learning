# %% [markdown]
# ## Exercise 05
#
# # Neural networks
#
# ## 4.1 Little Red Riding Hood Network
#
# Train a neural network to solve the  Little Red Riding Hood problem in sklern and Keras. Try the neural networ with different inputs and report the results.
#
# ________________

# %% [markdown]
# ### Using keras

# %%
import numpy as np

x_train = np.array([[1,1,0,0],[0,1,1,0],[0,0,0,1]])
y_train = np.array([[1,0,0,0],[0,0,1,1],[0,1,1,0]])

# %%
import pandas as pd
import keras
# Out:
# Using TensorFlow backend.

# %%
def lrrh_input(vals):
    return pd.DataFrame(vals[0],index=['big ears', 'big teeth', 'handsome', 'wrinkled'], columns=['input'])

def lrrh_output(vals):
    return pd.DataFrame(vals[0],index=['scream', 'hug', 'offer food', 'kiss cheek'], columns=['output'])

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()

model.add(Dense(units=3, input_dim=4))
model.add(Activation('sigmoid'))
model.add(Dense(units=4))
model.add(Activation('sigmoid'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 3)                 15
# _________________________________________________________________
# activation_1 (Activation)    (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 16
# _________________________________________________________________
# activation_2 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers import SGD
model.compile(loss = 'binary_crossentropy',
              optimizer = SGD(lr=0.01, momentum=0.9, decay=0.0, nesterov=False),
              metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
#  - 1s - loss: 0.6783 - acc: 0.6667
# Epoch 2/1000
#  - 0s - loss: 0.6782 - acc: 0.6667
# Epoch 3/1000
#  - 0s - loss: 0.6780 - acc: 0.6667
# Epoch 4/1000
#  - 0s - loss: 0.6778 - acc: 0.6667
# Epoch 5/1000
#  - 0s - loss: 0.6775 - acc: 0.6667
# Epoch 6/1000
#  - 0s - loss: 0.6772 - acc: 0.6667
# Epoch 7/1000
#  - 0s - loss: 0.6768 - acc: 0.6667
# Epoch 8/1000
#  - 0s - loss: 0.6763 - acc: 0.6667
# Epoch 9/1000
#  - 0s - loss: 0.6759 - acc: 0.6667
# Epoch 10/1000
#  - 0s - loss: 0.6753 - acc: 0.6667
# Epoch 11/1000
#  - 0s - loss: 0.6748 - acc: 0.6667
# Epoch 12/1000
#  - 0s - loss: 0.6743 - acc: 0.6667
# Epoch 13/1000
#  - 0s - loss: 0.6737 - acc: 0.6667
# Epoch 14/1000
#  - 0s - loss: 0.6731 - acc: 0.6667
# Epoch 15/1000
#  - 0s - loss: 0.6725 - acc: 0.6667
# Epoch 16/1000
#  - 0s - loss: 0.6719 - acc: 0.6667
# Epoch 17/1000
#  - 0s - loss: 0.6712 - acc: 0.6667
# Epoch 18/1000
#  - 0s - loss: 0.6706 - acc: 0.6667
# Epoch 19/1000
#  - 0s - loss: 0.6700 - acc: 0.6667
# Epoch 20/1000
#  - 0s - loss: 0.6693 - acc: 0.6667
# Epoch 21/1000
#  - 0s - loss: 0.6687 - acc: 0.6667
# Epoch 22/1000
#  - 0s - loss: 0.6680 - acc: 0.6667
# Epoch 23/1000
#  - 0s - loss: 0.6674 - acc: 0.6667
# Epoch 24/1000
#  - 0s - loss: 0.6668 - acc: 0.6667
# Epoch 25/1000
#  - 0s - loss: 0.6661 - acc: 0.6667
# Epoch 26/1000
#  - 0s - loss: 0.6655 - acc: 0.6667
# Epoch 27/1000
#  - 0s - loss: 0.6649 - acc: 0.6667
# Epoch 851/1000
#  - 0s - loss: 0.3822 - acc: 0.9167
# Epoch 852/1000
#  - 0s - loss: 0.3818 - acc: 0.9167
# Epoch 853/1000
#  - 0s - loss: 0.3814 - acc: 0.9167
# Epoch 854/1000
#  - 0s - loss: 0.3810 - acc: 0.9167
# Epoch 855/1000
#  - 0s - loss: 0.3805 - acc: 0.9167
# Epoch 856/1000
#  - 0s - loss: 0.3801 - acc: 0.9167
# Epoch 857/1000
#  - 0s - loss: 0.3797 - acc: 0.9167
# Epoch 858/1000
#  - 0s - loss: 0.3793 - acc: 0.9167
# Epoch 859/1000
#  - 0s - loss: 0.3789 - acc: 0.9167
# Epoch 860/1000
#  - 0s - loss: 0.3785 - acc: 0.9167
# Epoch 861/1000
#  - 0s - loss: 0.3780 - acc: 0.9167
# Epoch 862/1000
#  - 0s - loss: 0.3776 - acc: 0.9167
# Epoch 863/1000
#  - 0s - loss: 0.3772 - acc: 0.9167
# Epoch 864/1000
#  - 0s - loss: 0.3768 - acc: 0.9167
# Epoch 865/1000
#  - 0s - loss: 0.3764 - acc: 0.9167
# Epoch 866/1000
#  - 0s - loss: 0.3760 - acc: 0.9167
# Epoch 867/1000
#  - 0s - loss: 0.3755 - acc: 0.9167
# Epoch 868/1000
#  - 0s - loss: 0.3751 - acc: 0.9167
# Epoch 869/1000
#  - 0s - loss: 0.3747 - acc: 0.9167
# Epoch 870/1000
#  - 0s - loss: 0.3743 - acc: 0.9167
# Epoch 871/1000
#  - 0s - loss: 0.3739 - acc: 0.9167
# Epoch 872/1000
#  - 0s - loss: 0.3735 - acc: 0.9167
# Epoch 873/1000
#  - 0s - loss: 0.3730 - acc: 0.9167
# Epoch 874/1000
#  - 0s - loss: 0.3726 - acc: 0.9167
# Epoch 875/1000
#  - 0s - loss: 0.3722 - acc: 0.9167
# Epoch 876/1000
#  - 0s - loss: 0.3718 - acc: 0.9167
# Epoch 877/1000
#  - 0s - loss: 0.3714 - acc: 0.9167
# Epoch 878/1000
#  - 0s - loss: 0.3710 - acc: 0.9167
# Epoch 879/1000
#  - 0s - loss: 0.3705 - acc: 0.9167
# Epoch 880/1000
#  - 0s - loss: 0.3701 - acc: 0.9167
# Epoch 881/1000
#  - 0s - loss: 0.3697 - acc: 0.9167
# Epoch 882/1000
#  - 0s - loss: 0.3693 - acc: 0.9167
# Epoch 883/1000
#  - 0s - loss: 0.3689 - acc: 0.9167
# Epoch 884/1000
#  - 0s - loss: 0.3685 - acc: 0.9167
# Epoch 885/1000
#  - 0s - loss: 0.3681 - acc: 0.9167
# Epoch 886/1000
#  - 0s - loss: 0.3676 - acc: 0.9167
# Epoch 887/1000
#  - 0s - loss: 0.3672 - acc: 0.9167
# Epoch 888/1000
#  - 0s - loss: 0.3668 - acc: 0.9167
# Epoch 889/1000
#  - 0s - loss: 0.3664 - acc: 0.9167
# Epoch 890/1000
#  - 0s - loss: 0.3660 - acc: 0.9167
# Epoch 891/1000
#  - 0s - loss: 0.3656 - acc: 0.9167
# Epoch 892/1000
#  - 0s - loss: 0.3652 - acc: 0.9167
# Epoch 893/1000
#  - 0s - loss: 0.3647 - acc: 0.9167
# Epoch 894/1000
#  - 0s - loss: 0.3643 - acc: 0.9167
# Epoch 895/1000
#  - 0s - loss: 0.3639 - acc: 0.9167
# Epoch 896/1000
#  - 0s - loss: 0.3635 - acc: 0.9167
# Epoch 897/1000
#  - 0s - loss: 0.3631 - acc: 0.9167
# Epoch 898/1000
#  - 0s - loss: 0.3627 - acc: 0.9167
# Epoch 899/1000
#  - 0s - loss: 0.3623 - acc: 0.9167
# Epoch 900/1000
#  - 0s - loss: 0.3618 - acc: 0.9167
# Epoch 901/1000
#  - 0s - loss: 0.3614 - acc: 0.9167
# Epoch 902/1000
#  - 0s - loss: 0.3610 - acc: 0.9167
# Epoch 903/1000
#  - 0s - loss: 0.3606 - acc: 0.9167
# Epoch 904/1000
#  - 0s - loss: 0.3602 - acc: 0.9167
# Epoch 905/1000
#  - 0s - loss: 0.3598 - acc: 0.9167
# Epoch 906/1000
#  - 0s - loss: 0.3594 - acc: 0.9167
# Epoch 907/1000
#  - 0s - loss: 0.3590 - acc: 0.9167
# Epoch 908/1000
#  - 0s - loss: 0.3585 - acc: 0.9167
# Epoch 909/1000
#  - 0s - loss: 0.3581 - acc: 0.9167
# Epoch 910/1000
#  - 0s - loss: 0.3577 - acc: 0.9167
# Epoch 911/1000
#  - 0s - loss: 0.3573 - acc: 0.9167
# Epoch 912/1000
#  - 0s - loss: 0.3569 - acc: 0.9167
# Epoch 913/1000
#  - 0s - loss: 0.3565 - acc: 0.9167
# Epoch 914/1000
#  - 0s - loss: 0.3561 - acc: 0.9167
# Epoch 915/1000
#  - 0s - loss: 0.3557 - acc: 0.9167
# Epoch 916/1000
#  - 0s - loss: 0.3553 - acc: 0.9167
# Epoch 917/1000
#  - 0s - loss: 0.3548 - acc: 0.9167
# Epoch 918/1000
#  - 0s - loss: 0.3544 - acc: 0.9167
# Epoch 919/1000
#  - 0s - loss: 0.3540 - acc: 0.9167
# Epoch 920/1000
#  - 0s - loss: 0.3536 - acc: 0.9167
# Epoch 921/1000
#  - 0s - loss: 0.3532 - acc: 0.9167
# Epoch 922/1000
#  - 0s - loss: 0.3528 - acc: 0.9167
# Epoch 923/1000
#  - 0s - loss: 0.3524 - acc: 0.9167
# Epoch 924/1000
#  - 0s - loss: 0.3520 - acc: 0.9167
# Epoch 925/1000
#  - 0s - loss: 0.3516 - acc: 0.9167
# Epoch 926/1000
#  - 0s - loss: 0.3512 - acc: 0.9167
# Epoch 927/1000
#  - 0s - loss: 0.3508 - acc: 0.9167
# Epoch 928/1000
#  - 0s - loss: 0.3503 - acc: 0.9167
# Epoch 929/1000
#  - 0s - loss: 0.3499 - acc: 0.9167
# Epoch 930/1000
#  - 0s - loss: 0.3495 - acc: 0.9167
# Epoch 931/1000
#  - 0s - loss: 0.3491 - acc: 0.9167
# Epoch 932/1000
#  - 0s - loss: 0.3487 - acc: 1.0000
# Epoch 933/1000
#  - 0s - loss: 0.3483 - acc: 1.0000
# Epoch 934/1000
#  - 0s - loss: 0.3479 - acc: 1.0000
# Epoch 935/1000
#  - 0s - loss: 0.3475 - acc: 1.0000
# Epoch 936/1000
#  - 0s - loss: 0.3471 - acc: 1.0000
# Epoch 937/1000
#  - 0s - loss: 0.3467 - acc: 1.0000
# Epoch 938/1000
#  - 0s - loss: 0.3463 - acc: 1.0000
# Epoch 939/1000
#  - 0s - loss: 0.3459 - acc: 1.0000
# Epoch 940/1000
#  - 0s - loss: 0.3455 - acc: 1.0000
# Epoch 941/1000
#  - 0s - loss: 0.3450 - acc: 1.0000
# Epoch 942/1000
#  - 0s - loss: 0.3446 - acc: 1.0000
# Epoch 943/1000
#  - 0s - loss: 0.3442 - acc: 1.0000
# Epoch 944/1000
#  - 0s - loss: 0.3438 - acc: 1.0000
# Epoch 945/1000
#  - 0s - loss: 0.3434 - acc: 1.0000
# Epoch 946/1000
#  - 0s - loss: 0.3430 - acc: 1.0000
# Epoch 947/1000
#  - 0s - loss: 0.3426 - acc: 1.0000
# Epoch 948/1000
#  - 0s - loss: 0.3422 - acc: 1.0000
# Epoch 949/1000
#  - 0s - loss: 0.3418 - acc: 1.0000
# Epoch 950/1000
#  - 0s - loss: 0.3414 - acc: 1.0000
# Epoch 951/1000
#  - 0s - loss: 0.3410 - acc: 1.0000
# Epoch 952/1000
#  - 0s - loss: 0.3406 - acc: 1.0000
# Epoch 953/1000
#  - 0s - loss: 0.3402 - acc: 1.0000
# Epoch 954/1000
#  - 0s - loss: 0.3398 - acc: 1.0000
# Epoch 955/1000
#  - 0s - loss: 0.3394 - acc: 1.0000
# Epoch 956/1000
#  - 0s - loss: 0.3390 - acc: 1.0000
# Epoch 957/1000
#  - 0s - loss: 0.3386 - acc: 1.0000
# Epoch 958/1000
#  - 0s - loss: 0.3382 - acc: 1.0000
# Epoch 959/1000
#  - 0s - loss: 0.3378 - acc: 1.0000
# Epoch 960/1000
#  - 0s - loss: 0.3374 - acc: 1.0000
# Epoch 961/1000
#  - 0s - loss: 0.3370 - acc: 1.0000
# Epoch 962/1000
#  - 0s - loss: 0.3366 - acc: 1.0000
# Epoch 963/1000
#  - 0s - loss: 0.3362 - acc: 1.0000
# Epoch 964/1000
#  - 0s - loss: 0.3358 - acc: 1.0000
# Epoch 965/1000
#  - 0s - loss: 0.3354 - acc: 1.0000
# Epoch 966/1000
#  - 0s - loss: 0.3350 - acc: 1.0000
# Epoch 967/1000
#  - 0s - loss: 0.3346 - acc: 1.0000
# Epoch 968/1000
#  - 0s - loss: 0.3342 - acc: 1.0000
# Epoch 969/1000
#  - 0s - loss: 0.3338 - acc: 1.0000
# Epoch 970/1000
#  - 0s - loss: 0.3333 - acc: 1.0000
# Epoch 971/1000
#  - 0s - loss: 0.3329 - acc: 1.0000
# Epoch 972/1000
#  - 0s - loss: 0.3326 - acc: 1.0000
# Epoch 973/1000
#  - 0s - loss: 0.3322 - acc: 1.0000
# Epoch 974/1000
#  - 0s - loss: 0.3318 - acc: 1.0000
# Epoch 975/1000
#  - 0s - loss: 0.3314 - acc: 1.0000
# Epoch 976/1000
#  - 0s - loss: 0.3310 - acc: 1.0000
# Epoch 977/1000
#  - 0s - loss: 0.3306 - acc: 1.0000
# Epoch 978/1000
#  - 0s - loss: 0.3302 - acc: 1.0000
# Epoch 979/1000
#  - 0s - loss: 0.3298 - acc: 1.0000
# Epoch 980/1000
#  - 0s - loss: 0.3294 - acc: 1.0000
# Epoch 981/1000
#  - 0s - loss: 0.3290 - acc: 1.0000
# Epoch 982/1000
#  - 0s - loss: 0.3286 - acc: 1.0000
# Epoch 983/1000
#  - 0s - loss: 0.3282 - acc: 1.0000
# Epoch 984/1000
#  - 0s - loss: 0.3278 - acc: 1.0000
# Epoch 985/1000
#  - 0s - loss: 0.3274 - acc: 1.0000
# Epoch 986/1000
#  - 0s - loss: 0.3270 - acc: 1.0000
# Epoch 987/1000
#  - 0s - loss: 0.3266 - acc: 1.0000
# Epoch 988/1000
#  - 0s - loss: 0.3262 - acc: 1.0000
# Epoch 989/1000
#  - 0s - loss: 0.3258 - acc: 1.0000
# Epoch 990/1000
#  - 0s - loss: 0.3254 - acc: 1.0000
# Epoch 991/1000
#  - 0s - loss: 0.3250 - acc: 1.0000
# Epoch 992/1000
#  - 0s - loss: 0.3246 - acc: 1.0000
# Epoch 993/1000
#  - 0s - loss: 0.3242 - acc: 1.0000
# Epoch 994/1000
#  - 0s - loss: 0.3238 - acc: 1.0000
# Epoch 995/1000
#  - 0s - loss: 0.3234 - acc: 1.0000
# Epoch 996/1000
#  - 0s - loss: 0.3230 - acc: 1.0000
# Epoch 997/1000
#  - 0s - loss: 0.3226 - acc: 1.0000
# Epoch 998/1000
#  - 0s - loss: 0.3222 - acc: 1.0000
# Epoch 999/1000
#  - 0s - loss: 0.3219 - acc: 1.0000
# Epoch 1000/1000
#  - 0s - loss: 0.3215 - acc: 1.0000

# %%
model.weights
# Out:
# [<tf.Variable 'dense_1/kernel:0' shape=(4, 3) dtype=float32_ref>,
#  <tf.Variable 'dense_1/bias:0' shape=(3,) dtype=float32_ref>,
#  <tf.Variable 'dense_2/kernel:0' shape=(3, 4) dtype=float32_ref>,
#  <tf.Variable 'dense_2/bias:0' shape=(4,) dtype=float32_ref>]

# %%
model.get_weights()
# Out:
# [array([[ 0.80477625,  0.33624473, -1.90783441],
#         [ 0.89528906,  0.55616611, -1.03913867],
#         [ 0.83191997, -1.79385424,  2.12415409],
#         [-0.69377905,  1.08658445,  1.55602944]], dtype=float32),
#  array([-0.14779441,  0.06971802,  0.5546819 ], dtype=float32),
#  array([[-0.01465977, -1.48897755, -0.94889194,  0.32319468],
#         [ 0.59183061,  0.15292375, -0.32705989, -2.05766368],
#         [-2.70815682,  0.94674915,  2.76538372,  0.89140326]], dtype=float32),
#  array([ 0.41243565, -0.391164  ,  0.05990157, -0.27702269], dtype=float32)]

# %%
model.evaluate(x_train,y_train)
# Out:
# 3/3 [==============================] - 0s 53ms/step
# [0.32107022404670715, 1.0]

# %%
model.metrics_names
# Out:
# ['loss', 'acc']

# %%
in_vals = np.array([[1,1,0,0]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       1
# big teeth      1
# handsome       0
# wrinkled       0

# %%
lrrh_output(model.predict(in_vals))
# Out:
#               output
# scream      0.646048
# hug         0.193102
# offer food  0.325596
# kiss cheek  0.193963

# %%
in_vals = np.array([[0,1,1,0]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      1
# handsome       1
# wrinkled       0

# %%
lrrh_output(model.predict(in_vals))
# Out:
#               output
# scream      0.150922
# hug         0.310767
# offer food  0.819292
# kiss cheek  0.562021

# %%
in_vals = np.array([[0,0,1,1]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      0
# handsome       1
# wrinkled       1

# %%
lrrh_output(model.predict(in_vals))
# Out:
#               output
# scream      0.113076
# hug         0.463579
# offer food  0.900299
# kiss cheek  0.512730

# %%
in_vals = np.array([[0,0,0,1]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      0
# handsome       0
# wrinkled       1

# %%
lrrh_output(model.predict(in_vals))
# Out:
#               output
# scream      0.174033
# hug         0.530242
# offer food  0.879940
# kiss cheek  0.278929

# %% [markdown]
# ### Using sklern

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5), random_state=1, max_iter=2000, learning_rate_init=0.01)
clf.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=5, learning_rate='constant',
#        learning_rate_init=0.01, max_iter=2000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
clf.predict([[1,1,0,0]])
# Out:
# array([[1, 0, 0, 0]])

# %%
clf.predict([[0,1,1,0]])
# Out:
# array([[0, 0, 1, 1]])

# %%
clf.predict([[0,0,0,1]])
# Out:
# array([[0, 1, 1, 0]])

# %%
in_vals = np.array([[1,1,0,0]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       1
# big teeth      1
# handsome       0
# wrinkled       0

# %%
lrrh_output(clf.predict(in_vals))
# Out:
#             output
# scream           1
# hug              0
# offer food       0
# kiss cheek       0

# %%
in_vals = np.array([[0,1,1,0]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      1
# handsome       1
# wrinkled       0

# %%
in_vals = np.array([[0,0,1,1]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      0
# handsome       1
# wrinkled       1

# %%
lrrh_output(clf.predict(in_vals))
# Out:
#             output
# scream           0
# hug              0
# offer food       1
# kiss cheek       1

# %%
in_vals = np.array([[0,0,0,1]])
lrrh_input(in_vals)
# Out:
#            input
# big ears       0
# big teeth      0
# handsome       0
# wrinkled       1

# %%
lrrh_output(clf.predict(in_vals))
# Out:
#             output
# scream           0
# hug              1
# offer food       1
# kiss cheek       0

# %% [markdown]
# ## 4.2 Boston House Price Prediction
#
# In the next questions we are going to work using the dataset *Boston*. This dataset measures the influence of socioeconomical factors on the price of several estates of the city of Boston. This dataset has 506 instances, each one characterized by 13 features:
#
# * CRIM - per capita crime rate by town
# * ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# * INDUS - proportion of non-retail business acres per town.
# * CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# * NOX - nitric oxides concentration (parts per 10 million)
# * RM - average number of rooms per dwelling
# * AGE - proportion of owner-occupied units built prior to 1940
# * DIS - weighted distances to five Boston employment centres
# * RAD - index of accessibility to radial highways
# * TAX - full-value property-tax rate per 10,000 USD
# * PTRATIO - pupil-teacher ratio by town
# * B - $1000(Bk - 0.63)^2$ where $Bk$ is the proportion of blacks by town
# * LSTAT - % lower status of the population
#
# Output variable:
# * MEDV - Median value of owner-occupied homes in 1000's USD
#
# **Note:** In this exercise we are going to predict the price of each estate, which is represented in the `MEDV` variable. It is important to remember that we are always aiming to predict `MEDV`, no matter which explanatory variables we are using. That means, in some cases we will use a subset of the 13 previously mentioned variables, while in other cases we will use all the 13 variables. But in no case we will change the dependent variable $y$.
#
#
#
# 1. Load the dataset using `from sklearn.datasets import load_boston`.
# 2. Create a DataFrame using the attribute `.data` from the loading function of Scikit-learn.
# 3. Assign the columns of the DataFrame so they match the `.feature_names` attribute from the loading function of Scikit-learn.
# 4. Assign a new column to the DataFrame which holds the value to predict, that means, the `.target` attribute of the loading function of Scikit-learn. The name of this columns must be `MEDV`.
# 5. Use the function `.describe()` from Pandas for obtaining statistics about each column.

# %%
import pandas_profiling #Ejecutar "pip install geopy" en Anaconda Prompt

# %matplotlib inline
import matplotlib.pyplot as plt

# read the data and set the datetime as the index
import zipfile
import geopy.distance #Ejecutar "pip install geopy" en Anaconda Prompt

import numpy as np
import pandas as pd
import pandas_profiling
from sklearn import metrics

# module to do statistics
import scipy.stats  as stats
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
import statsmodels.api as sm
from statsmodels.formula.api import ols
from pandas.tools.plotting import scatter_matrix
from statsmodels.graphics.regressionplots import influence_plot
import scipy.stats as stats# Funciones adicionales
from sklearn import linear_model
import statsmodels.formula.api as smf
from sklearn import preprocessing
from string import ascii_letters
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from sklearn.datasets import load_boston
boston = load_boston()

# %%
Boston= pd.DataFrame(boston.data, columns=boston.feature_names)

# %%
Boston[0:5]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
Boston['MEDV']=boston.target

# %%
Boston[0:5]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
Boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
Boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# ## 4.3 Feature analysis:
#
# Using the DataFrame generated in the previous section:
# * Filter the dataset to just these features:
#      * Explanatory: 'LSTAT', 'INDUS', 'NOX', 'RM', 'AGE'
#      * Dependent: 'MEDV'.
# * Generate a scatter matrix among the features mentioned above using Pandas (`scatter_matrix`) or Seaborn (` pairplot`).
#      * Do you find any relationship between the features?
# * Generate the correlation matrix between these variables using `numpy.corrcoef`. Also include `MEDV`.
#      * Which characteristics are more correlated?
#      * BONUS: Visualize this matrix as heat map using Pandas, Matplotlib or Seaborn.

# %%
Explanatory=Boston.filter(items=['LSTAT', 'INDUS', 'NOX', 'RM', 'AGE'])
Explanatory[0:5]
# Out:
#    LSTAT  INDUS    NOX     RM   AGE
# 0   4.98   2.31  0.538  6.575  65.2
# 1   9.14   7.07  0.469  6.421  78.9
# 2   4.03   7.07  0.469  7.185  61.1
# 3   2.94   2.18  0.458  6.998  45.8
# 4   5.33   2.18  0.458  7.147  54.2

# %%
Dependent=Boston.filter(items=['MEDV'])
Dependent[0:5]
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
Exp_Dep=Boston.filter(items=['LSTAT', 'INDUS', 'NOX', 'RM', 'AGE','MEDV'])

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
Pairplot = sns.pairplot(Exp_Dep)

# %%
np.corrcoef(Exp_Dep, rowvar=False)
# Out:
# array([[ 1.        ,  0.60379972,  0.59087892, -0.61380827,  0.60233853,
#         -0.73766273],
#        [ 0.60379972,  1.        ,  0.76365145, -0.39167585,  0.64477851,
#         -0.48372516],
#        [ 0.59087892,  0.76365145,  1.        , -0.30218819,  0.7314701 ,
#         -0.42732077],
#        [-0.61380827, -0.39167585, -0.30218819,  1.        , -0.24026493,
#          0.69535995],
#        [ 0.60233853,  0.64477851,  0.7314701 , -0.24026493,  1.        ,
#         -0.37695457],
#        [-0.73766273, -0.48372516, -0.42732077,  0.69535995, -0.37695457,
#          1.        ]])

# %%
Corr = Exp_Dep.corr()
Corr
# Out:
#           LSTAT     INDUS       NOX        RM       AGE      MEDV
# LSTAT  1.000000  0.603800  0.590879 -0.613808  0.602339 -0.737663
# INDUS  0.603800  1.000000  0.763651 -0.391676  0.644779 -0.483725
# NOX    0.590879  0.763651  1.000000 -0.302188  0.731470 -0.427321
# RM    -0.613808 -0.391676 -0.302188  1.000000 -0.240265  0.695360
# AGE    0.602339  0.644779  0.731470 -0.240265  1.000000 -0.376955
# MEDV  -0.737663 -0.483725 -0.427321  0.695360 -0.376955  1.000000

# %%
mask = np.zeros_like(Corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(Corr,annot=True, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## 4.4 Modeling linear and non linear relationships
#
# * Generate two new subsets filtering these characteristics:
#      * $D_1$:  $X = \textit{'RM'}$, $y = \textit{'MEDV'}$
#      * $D_2$:  $X = \textit{'LSTAT'}$, $y = \textit{'MEDV'}$
# * For each subset, generate a training partition and a test partition using a ratio of $ 70 \% - 30 \% $
# * Train a linear regression model on both subsets of data:
#      * Report the mean square error on the test set
#      * Print the values of $ w $ and $ w_0 $ of the regression equation
#      * Generate a graph where you visualize the line obtained by the regression model in conjunction with the training data and the test data
# * How does the model perform on $ D_1 $ and $ D_2 $? Why?

# %% [markdown]
# ### D1

# %%
D1=Boston.filter(items=['RM', 'MEDV'])

# %%
X = D1.RM
y = D1.MEDV

# %%
from sklearn.model_selection import train_test_split
X_trainD1, X_testD1, y_trainD1, y_testD1 = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = smf.OLS(y_trainD1, X_trainD1)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     3262.
# Date:                Mon, 25 Jun 2018   Prob (F-statistic):          2.08e-180
# Time:                        22:00:57   Log-Likelihood:                -1227.9
# No. Observations:                 354   AIC:                             2458.
# Df Residuals:                     353   BIC:                             2462.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# RM             3.7082      0.065     57.118      0.000       3.581       3.836
# ==============================================================================
# Omnibus:                       54.002   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.128
# Skew:                           0.878   Prob(JB):                     3.63e-21
# Kurtosis:                       4.816   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
# Parameters:  RM    3.708214
# dtype: float64
# R2:  0.9023625043757073

# %%
# Obteniendo fitted values
fit=results.fittedvalues;
# Obteniendo residuos
Residuos=results.resid;
Gráfico = sm.qqplot(Residuos, stats.t, fit=True, line='45')

# %%
y_pred= results.predict(X_testD1)

# %%
print('MAE:', metrics.mean_absolute_error(y_testD1, y_pred))
print('MSE:', metrics.mean_squared_error(y_testD1, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_testD1, y_pred)))
# Out:
# MAE: 5.396375507518331
# MSE: 54.40340969685179
# RMSE: 7.37586670818093

# %%
plt.scatter(X_trainD1, y_trainD1,  color='green')
plt.scatter(X_testD1, y_testD1,  color='blue')
plt.plot(X_testD1, y_pred, color='red', linewidth=3)

# %% [markdown]
# ### D2

# %%
D2=Boston.filter(items=['LSTAT','MEDV'])

# %%
X = D2.LSTAT
y = D2.MEDV

# %%
X_trainD2, X_testD2, y_trainD2, y_testD2 = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = smf.OLS(y_trainD2, X_trainD2)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.439
# Method:                 Least Squares   F-statistic:                     278.5
# Date:                Mon, 25 Jun 2018   Prob (F-statistic):           1.68e-46
# Time:                        22:02:07   Log-Likelihood:                -1536.7
# No. Observations:                 354   AIC:                             3075.
# Df Residuals:                     353   BIC:                             3079.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# LSTAT          1.1534      0.069     16.687      0.000       1.017       1.289
# ==============================================================================
# Omnibus:                        0.151   Durbin-Watson:                   1.588
# Prob(Omnibus):                  0.927   Jarque-Bera (JB):                0.175
# Skew:                           0.050   Prob(JB):                        0.916
# Kurtosis:                       2.955   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
# Parameters:  LSTAT    1.15341
# dtype: float64
# R2:  0.44098070137566237

# %%
# Obteniendo fitted values
fit=results.fittedvalues;
# Obteniendo residuos
Residuos=results.resid;
Gráfico = sm.qqplot(Residuos, stats.t, fit=True, line='45')

# %%
y_pred= results.predict(X_testD2)

# %%
print('MAE:', metrics.mean_absolute_error(y_testD2, y_pred))
print('MSE:', metrics.mean_squared_error(y_testD2, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_testD2, y_pred)))
# Out:
# MAE: 13.214232032604414
# MSE: 283.4235756237863
# RMSE: 16.835188612658495

# %%
plt.scatter(X_testD2, y_testD2,  color='blue')
plt.scatter(X_trainD2, y_trainD2,  color='green')
plt.plot(X_testD2, y_pred, color='red', linewidth=3)

# %% [markdown]
# ## 4.5 Training a regression model
#
# * Generate a 70-30 partitioning of the data **using all the features**. (Do not include the dependent variable `MEDV`)
# * Train a linear regression model with the objective of predicting the output variable `MEDV`.
#      * Report the mean square error on the test set
# * Train a regression model using `MLPRegressor` in order to predict the output variable` MEDV`.
#      * Report the mean square error on the test set
# * Scale the data so that they have zero mean variance one per feature (only $ X $). You can use the following piece of code:
#
# ```python
# from sklearn.preprocessing import StandardScaler
#
# sc_x = StandardScaler()
# sc_x.fit(X)
# X_train_s = sc_x.transform(X_train)
# X_test_s = sc_x.transform(X_test)
# ```
# Check more information about `StandardScaler` [here](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html).
#
# * Train the following models:
#      1. Train a linear regression model using the scaled data.
#          * Report the mean square error on the test set
#      2. Train a regression model using a 2-layer MultiLayer Perceptron (128 neurons in the first and 512 in the second) and with the **scaled data**.
#          * Report the mean square error on the test set
#      3. Which model has better performance? Why?

# %%
Boston[0:5]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
All = Boston[['CRIM','ZN','INDUS','CHAS','NOX', 'RM', 'AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']]

# %%
y = Boston['MEDV']
X = Boston.drop('MEDV', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_trainD1, X_testD1, y_trainD1, y_testD1 = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = smf.OLS(y_trainD1, X_trainD1)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     638.8
# Date:                Tue, 26 Jun 2018   Prob (F-statistic):          2.36e-230
# Time:                        18:27:59   Log-Likelihood:                -1067.5
# No. Observations:                 354   AIC:                             2161.
# Df Residuals:                     341   BIC:                             2211.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CRIM          -0.1187      0.042     -2.823      0.005      -0.201      -0.036
# ZN             0.0383      0.018      2.092      0.037       0.002       0.074
# INDUS          0.0384      0.076      0.509      0.611      -0.110       0.187
# CHAS           3.0619      1.076      2.846      0.005       0.946       5.178
# NOX           -2.1203      4.159     -0.510      0.611     -10.301       6.061
# RM             5.8383      0.373     15.662      0.000       5.105       6.572
# AGE           -0.0150      0.017     -0.899      0.369      -0.048       0.018
# DIS           -0.9190      0.233     -3.942      0.000      -1.377      -0.460
# RAD            0.1162      0.081      1.430      0.154      -0.044       0.276
# TAX           -0.0061      0.005     -1.275      0.203      -0.015       0.003
# PTRATIO       -0.4287      0.128     -3.344      0.001      -0.681      -0.177
# B              0.0168      0.003      5.045      0.000       0.010       0.023
# LSTAT         -0.4672      0.059     -7.860      0.000      -0.584      -0.350
# ==============================================================================
# Omnibus:                      133.730   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              844.236
# Skew:                           1.440   Prob(JB):                    4.75e-184
# Kurtosis:                       9.996   Cond. No.                     8.73e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print('Parameters: ', results.params)
print('R2: ', results.rsquared)
# Out:
# Parameters:  CRIM      -0.118659
# ZN         0.038311
# INDUS      0.038416
# CHAS       3.061881
# NOX       -2.120282
# RM         5.838331
# AGE       -0.015033
# DIS       -0.918957
# RAD        0.116169
# TAX       -0.006071
# PTRATIO   -0.428687
# B          0.016781
# LSTAT     -0.467227
# dtype: float64
# R2:  0.960559050136943

# %%
# Obteniendo fitted values
fit=results.fittedvalues;
# Obteniendo residuos
Residuos=results.resid;
Gráfico = sm.qqplot(Residuos, stats.t, fit=True, line='45')

# %%
y_pred= results.predict(X_testD1)
print('MAE:', metrics.mean_absolute_error(y_testD1, y_pred)) 
print('MSE:', metrics.mean_squared_error(y_testD1, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_testD1, y_pred)))
# Out:
# MAE: 3.2905209493359706
# MSE: 24.88891639940808
# RMSE: 4.988879272883649

# %%
from sklearn.neural_network import MLPRegressor

# %%
mlp = MLPRegressor(hidden_layer_sizes=(10,), max_iter=100, activation='relu',
                           random_state=1, learning_rate_init=0.01,)

# %%
y_trainD1 = np.array(y_trainD1)

# %%
X_trainD1 = np.array(X_trainD1)

# %%
reg = mlp.fit(y_trainD1, X_trainD1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-13394d5fd47a> in <module>()
# ----> 1 reg = mlp.fit(y_trainD1, X_trainD1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in fit(self, X, y)
#     618         self : returns a trained MLP model.
#     619         """
# --> 620         return self._fit(X, y, incremental=False)
#     621
#     622     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _fit(self, X, y, incremental)
#     329                              hidden_layer_sizes)
#     330
# --> 331         X, y = self._validate_input(X, y, incremental)
#     332         n_samples, n_features = X.shape
#     333
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#    1302     def _validate_input(self, X, y, incremental):
#    1303         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# -> 1304                          multi_output=True, y_numeric=True)
#    1305         if y.ndim == 2 and y.shape[1] == 1:
#    1306             y = column_or_1d(y, warn=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
#     453             _assert_all_finite(array)
#
# ValueError: Found array with dim 3. Estimator expected <= 2.
